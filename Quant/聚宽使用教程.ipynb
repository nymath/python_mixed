# %%
from jqdatasdk import *
auth('18323330059','Zny1780068440')  #账号是申请时所填写的手机号；密码为聚宽官网登录密码
# Out:
# auth success

# %%
stocks = list(get_all_securities(['stock']).index)

# %%
df = get_price(stocks, end_date='2022-01-30',count=40, frequency='1d', 
               fields='open')
# Out:
#              time         code   open
# 0      2021-12-03  002233.XSHE   9.80
# 1      2021-12-06  002233.XSHE   9.85
# 2      2021-12-07  002233.XSHE   9.87
# 3      2021-12-08  002233.XSHE   9.86
# 4      2021-12-09  002233.XSHE   9.73
# ...           ...          ...    ...
# 201155 2022-01-24  603566.XSHG  25.21
# 201156 2022-01-25  603566.XSHG  24.46
# 201157 2022-01-26  603566.XSHG  23.20
# 201158 2022-01-27  603566.XSHG  23.63
# 201159 2022-01-28  603566.XSHG  22.94
#
# [201160 rows x 3 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('code').apply(lambda x:)
# Out:
# code
# 000001.XSHE    <class 'pandas.core.frame.DataFrame'>
# 000002.XSHE    <class 'pandas.core.frame.DataFrame'>
# 000004.XSHE    <class 'pandas.core.frame.DataFrame'>
# 000005.XSHE    <class 'pandas.core.frame.DataFrame'>
# 000006.XSHE    <class 'pandas.core.frame.DataFrame'>
#                                ...
# 688799.XSHG    <class 'pandas.core.frame.DataFrame'>
# 688800.XSHG    <class 'pandas.core.frame.DataFrame'>
# 688819.XSHG    <class 'pandas.core.frame.DataFrame'>
# 688981.XSHG    <class 'pandas.core.frame.DataFrame'>
# 689009.XSHG    <class 'pandas.core.frame.DataFrame'>
# Length: 5029, dtype: object

# %%
df.pivot_table(values='time',index='time',columns='code')
# Out:
# code        000001.XSHE  000002.XSHE  000004.XSHE  000005.XSHE  000006.XSHE  \
# time
# 2021-12-03        17.33        17.92        18.38         2.23         4.07
# 2021-12-06        17.53        18.46        18.04         2.24         4.09
# 2021-12-07        17.98        18.97        18.19         2.28         4.10
# 2021-12-08        18.12        18.78        18.18         2.33         4.13
# 2021-12-09        18.16        18.72        18.33         2.27         4.09
# 2021-12-10        18.18        19.02        18.60         2.24         4.13
# 2021-12-13        18.14        18.91        18.81         2.25         4.17
# 2021-12-14        17.84        18.75        18.86         2.20         4.13
# 2021-12-15        17.20        18.28        19.18         2.21         4.11
# 2021-12-16        17.24        18.37        18.99         2.23         4.14
# 2021-12-17        17.39        18.63        19.26         2.25         4.16
# ...
